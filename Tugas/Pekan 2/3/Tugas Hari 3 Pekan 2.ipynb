# %%
import pandas as pd
import random

data = {
    'Tipe Ujian' : ['UTS1', 'UAS1', 'UTS2', 'UAS2']*3,
    'Mata Pelajaran' : ['Fisika']*4 + ['Matematika']*4+['Statistika']*4,
    'Rata2 Waktu Belajar (menit)' : [random.choice(range(200, 800)) for i in range(12)],
    'Rata2 Nilai Ujian' : [random.choice(range(40, 100)) for i in range(12)] 
}

df = pd.DataFrame(data)
df
# Out:
#    Tipe Ujian Mata Pelajaran  Rata2 Waktu Belajar (menit)  Rata2 Nilai Ujian
# 0        UTS1         Fisika                          756                 78
# 1        UAS1         Fisika                          646                 61
# 2        UTS2         Fisika                          398                 67
# 3        UAS2         Fisika                          405                 49
# 4        UTS1     Matematika                          795                 86
# 5        UAS1     Matematika                          273                 41
# 6        UTS2     Matematika                          754                 50
# 7        UAS2     Matematika                          746                 73
# 8        UTS1     Statistika                          581                 93
# 9        UAS1     Statistika                          481                 58
# 10       UTS2     Statistika                          452                 68
# 11       UAS2     Statistika                          725                 95

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
# ## Soal 1. Data Cleaning
#
# Lakukan sorting data berdasarkan Rata2 nilai ujian dari terbesar ke terkecil
#
# *   Lakukan sorting data berdasarkan Rata2 nilai ujian dari terbesar ke terkecil
# *   Tipe Ujian dan Mata pelajaran apakah yang memiliki rata2 nilai terkecil?

# %%
#code here
df.sort_values('Rata2 Nilai Ujian',ascending=False)
# Out:
#    Tipe Ujian Mata Pelajaran  Rata2 Waktu Belajar (menit)  Rata2 Nilai Ujian
# 11       UAS2     Statistika                          725                 95
# 8        UTS1     Statistika                          581                 93
# 4        UTS1     Matematika                          795                 86
# 0        UTS1         Fisika                          756                 78
# 7        UAS2     Matematika                          746                 73
# 10       UTS2     Statistika                          452                 68
# 2        UTS2         Fisika                          398                 67
# 1        UAS1         Fisika                          646                 61
# 9        UAS1     Statistika                          481                 58
# 6        UTS2     Matematika                          754                 50
# 3        UAS2         Fisika                          405                 49
# 5        UAS1     Matematika                          273                 41

# %% [markdown]
# Expected output:
#
# (Output bisa berbeda-beda)
#
# ![alt text](https://drive.google.com/uc?id=1iv8P-LDdN3WpTVX9qST3kL7QSNSDiOc2)

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
# ## Soal 2: Data Restructuring
#
# Jelaskan itu pivoting dan melting data

# %% [markdown]
# ### Pivoting
#
# Pivoting adalah suatu pengubahan bentuk data dengan memutar data yang terletak di baris menjadi di column. coba perhatikan gambar di bawah.
#
# <img src="ss/pivot.png" alt="drawing" width="500"/>
#
#
# ### Melting
#
# Melting adalah ‘unpivoting’, melting mengubah suatu data dengan memutar dari yang tadinya berada di posisi column menjadi di posisi row.
#
# Melting mengubah data yang tadinya lebar menjadi panjang.
#
# Melting berguna ketika ada suatu kasus dimana terdapat satu atau lebih column yang merupakan identifier variable, dan columnn lain adalah measure variabel. Identifier variabel adalah suatu entitias yang melakukan identifikasi terhadap suatu variabel yang sedang di ukur.
#
# <img src="ss/melt.png" alt="drawing" width="500"/>

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
# ## Soal 3: Reshaping Data 1

# %%
import pandas as pd
import random

data = {
    'Tipe Ujian' : ['UTS1', 'UAS1', 'UTS2', 'UAS2']*3,
    'Mata Pelajaran' : ['Fisika']*4 + ['Matematika']*4+['Statistika']*4,
    'Rata2 Waktu Belajar (menit)' : [random.choice(range(200, 800)) for i in range(12)],
    'Rata2 Nilai Ujian' : [random.choice(range(40, 100)) for i in range(12)] 
}

df = pd.DataFrame(data)
df
# Out:
#    Tipe Ujian Mata Pelajaran  Rata2 Waktu Belajar (menit)  Rata2 Nilai Ujian
# 0        UTS1         Fisika                          600                 48
# 1        UAS1         Fisika                          281                 75
# 2        UTS2         Fisika                          309                 98
# 3        UAS2         Fisika                          778                 53
# 4        UTS1     Matematika                          494                 41
# 5        UAS1     Matematika                          791                 45
# 6        UTS2     Matematika                          622                 41
# 7        UAS2     Matematika                          675                 95
# 8        UTS1     Statistika                          622                 44
# 9        UAS1     Statistika                          272                 71
# 10       UTS2     Statistika                          592                 87
# 11       UAS2     Statistika                          329                 55

# %% [markdown]
# Perhatikan data di atas, kemudian ubahlah bentuknya agar sesuai yang di harapkan.

# %%
#code here

pivot_df = pd.pivot(df, index='Tipe Ujian', columns='Mata Pelajaran', values=['Rata2 Nilai Ujian', 'Rata2 Waktu Belajar (menit)'])

pivot_df
# Out:
#                Rata2 Nilai Ujian                        \
# Mata Pelajaran            Fisika Matematika Statistika
# Tipe Ujian
# UAS1                          75         45         71
# UAS2                          53         95         55
# UTS1                          48         41         44
# UTS2                          98         41         87
#
#                Rata2 Waktu Belajar (menit)
# Mata Pelajaran                      Fisika Matematika Statistika
# Tipe Ujian
# UAS1                                   281        791        272
# UAS2                                   778        675        329
# UTS1                                   600        494        622
# UTS2                                   309        622        592

# %% [markdown]
# Expected Result:
#
# (Output bisa berbeda-beda)
#
# ![alt text](https://drive.google.com/uc?id=1XufsfqZe7-XZLsb92SpATexy-QRZE0ow)

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
# ## Soal 4: Reshaping Data 2

# %%
import pandas as pd

data = {
    'Hari' : ['Sabtu', 'Minggu'],
    'Kebun Binatang' : [271, 399],
    'Dufan' : [501, 700],
    'Disney' : [1000, 1001],
    'Bali' : [900, 803]
}
df = pd.DataFrame(data).set_index('Hari')
df
# Out:
#         Kebun Binatang  Dufan  Disney  Bali
# Hari
# Sabtu              271    501    1000   900
# Minggu             399    700    1001   803

# %% [markdown]
# diatas adalah data tentang jumlah pengunjung di berbagai tempat hiburan, ubahlah struktur data tersebut sehingga sesuai dengan hasil yang diharapkan.

# %%
#code here
df.reset_index(inplace=True)

pd.melt(df, id_vars =['Hari'], value_vars =['Kebun Binatang', 'Dufan', 'Disney', 'Bali'], var_name='Tempat Hiburan', value_name='Pengunjung')
# Out:
#      Hari  Tempat Hiburan  Pengunjung
# 0   Sabtu  Kebun Binatang         271
# 1  Minggu  Kebun Binatang         399
# 2   Sabtu           Dufan         501
# 3  Minggu           Dufan         700
# 4   Sabtu          Disney        1000
# 5  Minggu          Disney        1001
# 6   Sabtu            Bali         900
# 7  Minggu            Bali         803

# %% [markdown]
# Expected Result:
#
# (Output bisa berbeda-beda)
#
# ![alt text](https://drive.google.com/uc?id=159mIqcyfeD30EEcyZmmkovORa6cZDLtn)

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
# ## Soal 5: Data Enrichment
#
# Lakukan binning data menggunakan qcut sehingga sesuai hasil yang diharapkan

# %%
import pandas as pd
import random

data = {
    'Tipe Ujian' : ['UTS1', 'UAS1', 'UTS2', 'UAS2']*3,
    'Mata Pelajaran' : ['Fisika']*4 + ['Matematika']*4+['Statistika']*4,
    'Rata2 Waktu Belajar (menit)' : [random.choice(range(200, 800)) for i in range(12)],
    'Rata2 Nilai Ujian' : [random.choice(range(40, 100)) for i in range(12)] ,
}

df = pd.DataFrame(data)
df
# Out:
#    Tipe Ujian Mata Pelajaran  Rata2 Waktu Belajar (menit)  Rata2 Nilai Ujian
# 0        UTS1         Fisika                          377                 97
# 1        UAS1         Fisika                          735                 68
# 2        UTS2         Fisika                          682                 91
# 3        UAS2         Fisika                          364                 78
# 4        UTS1     Matematika                          634                 69
# 5        UAS1     Matematika                          308                 78
# 6        UTS2     Matematika                          542                 44
# 7        UAS2     Matematika                          603                 46
# 8        UTS1     Statistika                          277                 78
# 9        UAS1     Statistika                          457                 85
# 10       UTS2     Statistika                          520                 94
# 11       UAS2     Statistika                          486                 46

# %%
#code here

# PAKE CARA NUMPY

# import numpy as np

# criteria = [df['Rata2 Nilai Ujian'].between(1, 70), df['Rata2 Nilai Ujian'].between(71, 85), df['Rata2 Nilai Ujian'].between(86, 100)]
# values = ['tidak lulus', 'remedial', 'lulus']

# df['Keterangan kelulusan'] = np.select(criteria, values, 0)

# df

# %%
df['Keterangan kelulusan'] = df['Rata2 Nilai Ujian']


df
# Out:
#    Tipe Ujian Mata Pelajaran  Rata2 Waktu Belajar (menit)  Rata2 Nilai Ujian  \
# 0        UTS1         Fisika                          377                 97
# 1        UAS1         Fisika                          735                 68
# 2        UTS2         Fisika                          682                 91
# 3        UAS2         Fisika                          364                 78
# 4        UTS1     Matematika                          634                 69
# 5        UAS1     Matematika                          308                 78
# 6        UTS2     Matematika                          542                 44
# 7        UAS2     Matematika                          603                 46
# 8        UTS1     Statistika                          277                 78
# 9        UAS1     Statistika                          457                 85
# 10       UTS2     Statistika                          520                 94
# 11       UAS2     Statistika                          486                 46
#
#     Keterangan kelulusan
# 0                     97
# 1                     68
# 2                     91
# 3                     78
# 4                     69
# 5                     78
# 6                     44
# 7                     46
# 8                     78
# 9                     85
# 10                    94
# 11                    46

# %% [markdown]
# ---
#
#
#
# ---

# %%
labels = ['tidak lulus', 'remedial','lulus']

df['Keterangan kelulusan'] = pd.qcut(df['Keterangan kelulusan'], q=3 ,labels=labels)

df
# Out:
#    Tipe Ujian Mata Pelajaran  Rata2 Waktu Belajar (menit)  Rata2 Nilai Ujian  \
# 0        UTS1         Fisika                          377                 97
# 1        UAS1         Fisika                          735                 68
# 2        UTS2         Fisika                          682                 91
# 3        UAS2         Fisika                          364                 78
# 4        UTS1     Matematika                          634                 69
# 5        UAS1     Matematika                          308                 78
# 6        UTS2     Matematika                          542                 44
# 7        UAS2     Matematika                          603                 46
# 8        UTS1     Statistika                          277                 78
# 9        UAS1     Statistika                          457                 85
# 10       UTS2     Statistika                          520                 94
# 11       UAS2     Statistika                          486                 46
#
#    Keterangan kelulusan
# 0                 lulus
# 1           tidak lulus
# 2                 lulus
# 3              remedial
# 4              remedial
# 5              remedial
# 6           tidak lulus
# 7           tidak lulus
# 8              remedial
# 9                 lulus
# 10                lulus
# 11          tidak lulus

# %% [markdown]
# Expected Output:
#
# (Output bisa berbeda-beda)
#
# ![alt text](https://drive.google.com/uc?id=1h2_u5_xhD1_QtPpItTj-o3lljHhnr4XS)
