# %% [markdown]
# <h2>Soal 1: Helper Function</h2>
#
# Jawab Pertanyaan di bawah ini:
#
# Misalkan kamu ingin mengetahui tentang kegunaan fungsi 'len' di Python, maka fungsi apa yang bisa kamu gunakan untuk menolong kamu?

# %%
# lengkapi code ini

print(help(len))
# Out:
# Help on built-in function len in module builtins:
#
# len(obj, /)
#     Return the number of items in a container.
#
# None

# %% [markdown]
# <h2>Soal 2: Built-in Function</h2>
#
# Jawab Pertanyaan di bawah ini:
#
# Apa itu built-in Function?
#
# Sebutkan 3 built-in Function di pyhon!
#
# Berikan contoh masing2 1 cara penggunaan built-in function yang kamu sebutkan sebelumnya

# %% [markdown]
# //isi jawaban text disini
#
# Built-in function : fungsi bawaan yang bisa kita gunakan secara langsung.
#
# * abs( ) : untuk mengembalikan nilai absolute dari sebuah angka
# * sum( ) : untuk menjumlahkan nilai-nilai yang ada pada list (menjumlahkan item dari sebuah iterator)
# * max( ) : untuk mengembalikan nilai terbesar dari sebuah list

# %%
# Contoh penggunaan built in function

print(abs(-100))

list_a = [1,2,3,4,5]

print(sum(list_a))

print(max(list_a))
# Out:
# 100
# 15
# 5

# %% [markdown]
# <h2>Soal 3: Method dan Function</h2>
#
# Jawab Pertanyaan di bawah ini:
#
# - Apa perbedaan method dan function?

# %% [markdown]
# Method mirip dengan fungsi namun method dibuat oleh object/class. Perbedaan antara method dan function
#
# * Method secara implisit digunakan oleh objek yang dipanggil
# * Method dapat mengakses data yang terdapat pada kelas
#
#
#
# ```
# class ClassName:
#    def method_name():
#       …………..
#       # Method_body
#       ………………
#
# class Pet(object):
#    def my_method(self):
#       print("I am a Cat")
# cat = Pet()
# cat.my_method()
#
# #Output I am a Cat
# ```

# %% [markdown]
# <h2>Soal 4: Menggunkan Method String</h2>
#
# Lengkapi kode untuk menghasilkan suatu output yang di harapkan

# %%
kalimat = "ayo belajar data science"

# gunakan method untuk mengubah nilai kalimat menjadi uppercase semua kemudian tampilkan hasilnya

print(kalimat.upper())


# gunakan method untuk menghitung berapa huruf a di dalam kalimat
print(kalimat.count('a'))
# Out:
# AYO BELAJAR DATA SCIENCE
# 5

# %% [markdown]
# Expected Output:
#
# AYO BELAJAR DATA SCIENCE
#
# 5

# %% [markdown]
# <h2>Soal 5: Membuat Simple Function</h2>
#
# Buatlah suatu fungsi yang menerima satu input argumen berbentuk list dan mempunyai elemen bertipe numeric semua, dimana fungsi tersebut berguna untuk menghitung rata2 dari kumpulan elemen list tersebut. namai fungsi tersebut 'mean_list'

# %%
obj_list = [11.25, 18.0, 20.0, 10.75, 9.50, 13.45, 23.0, 7.0, 8.45, 2.50]

def mean_list(inp_list):
  return sum(inp_list)/len(inp_list)
 

print(mean_list(obj_list))
# Out:
# 12.39

# %% [markdown]
# Expected Output:
#
# 12.39

# %% [markdown]
# <h2>Soal 6: Membuat Function dengan Multiple arguments</h2>
#
# Buatlah suatu fungsi untuk melakukan penggabungan antara dua list

# %%
obj_list = [1, 2, 3, 4]
obj_penambah = [5, 6, 7]

def kali_list(inp_list1, inp_list2):
  inp_list1.extend(inp_list2)
  return inp_list1
 

print(kali_list(obj_list, obj_penambah))
# Out:
# [1, 2, 3, 4, 5, 6, 7]

# %% [markdown]
# Expected Output:
#
#
# [1, 2, 3, 4, 5, 6, 7]

# %% [markdown]
# # Soal 7. Mapping Fungsi lambda
#
# Hitunglah jumlah bilangan genap dari sebuah objek list berikut menggunakan lambda function

# %%
obj_list = [i for i in range(1000)]

hasil = len(list(filter(lambda x: (x % 2 != 0), obj_list)))



print(hasil)
# Out:
# 500

# %% [markdown]
# Expected output:
#
# 500
